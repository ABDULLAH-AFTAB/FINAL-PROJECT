# %% [markdown]
# **INSTALLING LIBRARIES**

# %%
import pandas as pd
import numpy as np
# !pip install pyspan
import pyspan as ps
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 55.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# **DATA EXPLORATION**

# %%
#Importing data

data=pd.read_csv('/content/World Energy Consumption.csv')
data.head(100)
# Out:
#           country  year iso_code  population           gdp  \
# 0   ASEAN (Ember)  2000      NaN         NaN           NaN
# 1   ASEAN (Ember)  2001      NaN         NaN           NaN
# 2   ASEAN (Ember)  2002      NaN         NaN           NaN
# 3   ASEAN (Ember)  2003      NaN         NaN           NaN
# 4   ASEAN (Ember)  2004      NaN         NaN           NaN
# ..            ...   ...      ...         ...           ...
# 95    Afghanistan  1972      AFG  11286753.0  1.317055e+10
# 96    Afghanistan  1973      AFG  11575308.0  1.356863e+10
# 97    Afghanistan  1974      AFG  11869881.0  1.430911e+10
# 98    Afghanistan  1975      AFG  12157390.0  1.517777e+10
# 99    Afghanistan  1976      AFG  12425276.0  1.602361e+10
#
#     biofuel_cons_change_pct  biofuel_cons_change_twh  biofuel_cons_per_capita  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# ...

# %%
#Total number of rows and column
data.shape
# Out:
# (22012, 129)

# %%
len(data.columns)
# Out:
# 129

# %%
data.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita',
#        ...
#        'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct',
#        'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita',
#        'wind_electricity', 'wind_energy_per_capita', 'wind_share_elec',
#        'wind_share_energy'],
#       dtype='object', length=129)

# %%
data.info
# Out:
# <bound method DataFrame.info of              country  year iso_code  population           gdp  \
# 0      ASEAN (Ember)  2000      NaN         NaN           NaN
# 1      ASEAN (Ember)  2001      NaN         NaN           NaN
# 2      ASEAN (Ember)  2002      NaN         NaN           NaN
# 3      ASEAN (Ember)  2003      NaN         NaN           NaN
# 4      ASEAN (Ember)  2004      NaN         NaN           NaN
# ...              ...   ...      ...         ...           ...
# 22007       Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 22008       Zimbabwe  2019      ZWE  15354606.0           NaN
# 22009       Zimbabwe  2020      ZWE  15669663.0           NaN
# 22010       Zimbabwe  2021      ZWE  15993525.0           NaN
# 22011       Zimbabwe  2022      ZWE  16320539.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# ...

# %%
#Check Nullls
pd.set_option('display.max_rows',None)
data.isnull().sum()
# Out:
# country                                             0
# year                                                0
# iso_code                                         5500
# population                                       3889
# gdp                                             10899
# biofuel_cons_change_pct                         20265
# biofuel_cons_change_twh                         19325
# biofuel_cons_per_capita                         19710
# biofuel_consumption                             19245
# biofuel_elec_per_capita                         16737
# biofuel_electricity                             16485
# biofuel_share_elec                              16520
# biofuel_share_energy                            19341
# carbon_intensity_elec                           16847
# coal_cons_change_pct                            16754
# coal_cons_change_twh                            16697
# coal_cons_per_capita                            17346
# ...

# %%
Select_columns=['country','year','biofuel_consumption','wind_consumption']
columns_df=data[Select_columns]
columns_df.head(10)
# Out:
#          country  year  biofuel_consumption  wind_consumption
# 0  ASEAN (Ember)  2000                  NaN               NaN
# 1  ASEAN (Ember)  2001                  NaN               NaN
# 2  ASEAN (Ember)  2002                  NaN               NaN
# 3  ASEAN (Ember)  2003                  NaN               NaN
# 4  ASEAN (Ember)  2004                  NaN               NaN
# 5  ASEAN (Ember)  2005                  NaN               NaN
# 6  ASEAN (Ember)  2006                  NaN               NaN
# 7  ASEAN (Ember)  2007                  NaN               NaN
# 8  ASEAN (Ember)  2008                  NaN               NaN
# 9  ASEAN (Ember)  2009                  NaN               NaN

# %%
data.dropna(axis=1, inplace=True)
data.dropna(axis=0, inplace=True)
data.head(10)
# Out:
#          country  year
# 0  ASEAN (Ember)  2000
# 1  ASEAN (Ember)  2001
# 2  ASEAN (Ember)  2002
# 3  ASEAN (Ember)  2003
# 4  ASEAN (Ember)  2004
# 5  ASEAN (Ember)  2005
# 6  ASEAN (Ember)  2006
# 7  ASEAN (Ember)  2007
# 8  ASEAN (Ember)  2008
# 9  ASEAN (Ember)  2009

# %%
# Drop rows with missing values
columns_df.dropna(inplace=True)

# Drop columns with missing values
columns_df.dropna(axis=1, inplace=True)

# Display the cleaned DataFrame
columns_df.head(100) #head() display the first few rows
# Out:
# <ipython-input-10-f3d6cc1d2373>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns_df.dropna(inplace=True)
# <ipython-input-10-f3d6cc1d2373>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns_df.dropna(axis=1, inplace=True)
#           country  year  biofuel_consumption  wind_consumption
# 235        Africa  1990                0.000             0.000
# 236        Africa  1991                0.000             0.000
# 237        Africa  1992                0.000             0.000
# 238        Africa  1993                0.000             0.006
# ...

# %%
columns_df['country'].unique()
# Out:
# array(['Africa', 'Africa (EI)', 'Argentina', 'Asia', 'Asia Pacific (EI)',
#        'Australia', 'Austria', 'Belarus', 'Belgium', 'Brazil', 'Bulgaria',
#        'CIS (EI)', 'Canada', 'Central America (EI)', 'China', 'Colombia',
#        'Croatia', 'Cyprus', 'Czechia', 'Denmark', 'Eastern Africa (EI)',
#        'Ecuador', 'Estonia', 'Europe', 'Europe (EI)',
#        'European Union (27)', 'Finland', 'France', 'Germany', 'Greece',
#        'High-income countries', 'Hong Kong', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Kazakhstan', 'Latvia', 'Lithuania',
#        'Lower-middle-income countries', 'Luxembourg', 'Malaysia',
#        'Mexico', 'Middle East (EI)', 'Netherlands', 'New Zealand',
#        'Non-OECD (EI)', 'North America', 'North America (EI)',
#        'North Macedonia', 'Norway', 'OECD (EI)', 'Oceania', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Romania', 'Russia',
# ...

# %%
columns_df['country'].value_counts()
# Out:
# country
# World                             58
# Sweden                            58
# Europe (EI)                       58
# Europe                            58
# OECD (EI)                         58
# Non-OECD (EI)                     58
# High-income countries             58
# Poland                            58
# European Union (27)               58
# Turkey                            58
# Upper-middle-income countries     58
# Asia                              58
# Asia Pacific (EI)                 58
# Slovakia                          52
# North America                     52
# Malaysia                          52
# South America                     52
# South and Central America (EI)    52
# Middle East (EI)                  45
# Brazil                            38
# Luxembourg                        33
# Lower-middle-income countries     33
# New Zealand                       33
# Lithuania                         33
# Mexico                            33
# ...

# %%
columns_df['year'].value_counts()
# Out:
# year
# 2019    80
# 2021    80
# 2022    80
# 2018    80
# 2017    80
# 2016    80
# 2015    80
# 2014    80
# 2013    80
# 2020    80
# 2010    79
# 2012    79
# 2011    79
# 2009    74
# 2008    74
# 2007    73
# 2006    70
# 2005    67
# 2004    67
# 2003    66
# 2002    64
# 2001    62
# 2000    62
# 1999    57
# 1998    56
# 1997    56
# 1996    56
# 1995    56
# 1994    53
# 1993    53
# 1992    53
# 1990    51
# 1991    51
# 1985    20
# 1988    20
# 1987    20
# 1986    20
# 1989    20
# 1980    19
# 1978    19
# 1984    19
# 1983    19
# 1982    19
# 1981    19
# 1979    19
# 1971    18
# 1977    18
# 1976    18
# 1975    18
# 1974    18
# 1973    18
# 1972    18
# 1965    13
# 1969    13
# 1968    13
# 1967    13
# 1966    13
# 1970    13
# Name: count, dtype: int64

# %%
Selected_continents=['Asia','Africa','North America (EI)','Europe']
Selected_years=range(2015,2023)
rows_df=columns_df[columns_df['country'].isin(Selected_continents)&columns_df['year'].isin(Selected_years)]
pd.set_option('display.max_rows',None)
rows_df
# Out:
#                   country  year  biofuel_consumption  wind_consumption
# 260                Africa  2015                0.714            23.996
# 261                Africa  2016                0.650            29.920
# 262                Africa  2017                0.637            36.227
# 263                Africa  2018                0.988            39.059
# 264                Africa  2019                0.855            50.826
# 265                Africa  2020                0.872            50.177
# 266                Africa  2021                1.110            59.609
# 267                Africa  2022                1.122            62.294
# 1264                 Asia  2015               88.450           648.833
# 1265                 Asia  2016              114.514           835.911
# 1266                 Asia  2017              109.429          1040.410
# 1267                 Asia  2018              139.131          1232.154
# ...

# %% [markdown]
# **DATA VISUALIZATION**

# %% [markdown]
# SCATTER PLOT

# %%
#Create a scatterplot
sns.scatterplot(x='biofuel_consumption', #X-axis
                 y='wind_consumption' #Y-axis
                 ,hue='country',
                 s=100,
                marker='v',
                 data=rows_df)
plt.legend(labels=Selected_continents)
plt.title("Biofuel and Wind Consumption");
plt.show()

# %%
plt.hist(rows_df['biofuel_consumption'], color='skyblue')
plt.show()

# %%
plt.hist(df_filtered['biofuel_consumption'], color='skyblue')
# Out:
# (array([8., 1., 2., 6., 6., 1., 0., 0., 2., 6.]),
#  array([  0.637 ,  46.5816,  92.5262, 138.4708, 184.4154, 230.36  ,
#         276.3046, 322.2492, 368.1938, 414.1384, 460.083 ]),
#  <BarContainer object of 10 artists>)

# %%
Q1=rows_df['biofuel_consumption'].quantile(0.25)
Q3=rows_df['biofuel_consumption'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
df_filtered=rows_df[(rows_df['biofuel_consumption']>=lower_bound)&(rows_df['biofuel_consumption']<=upper_bound)]
df_filtered
# Out:
#                   country  year  biofuel_consumption  wind_consumption
# 260                Africa  2015                0.714            23.996
# 261                Africa  2016                0.650            29.920
# 262                Africa  2017                0.637            36.227
# 263                Africa  2018                0.988            39.059
# 264                Africa  2019                0.855            50.826
# 265                Africa  2020                0.872            50.177
# 266                Africa  2021                1.110            59.609
# 267                Africa  2022                1.122            62.294
# 1264                 Asia  2015               88.450           648.833
# 1265                 Asia  2016              114.514           835.911
# 1266                 Asia  2017              109.429          1040.410
# 1267                 Asia  2018              139.131          1232.154
# ...

# %%
#Line Graph
sns.lineplot(data=rows_df,x='year',y='wind_consumption', hue='country',marker='o')
plt.title('Wind Consumption Over Years')
plt.show()

# %%
#Multile Histogram
Asia_df=rows_df[rows_df.country=='Asia']
Europe_df=rows_df[rows_df.country=='Europe']
North_America=rows_df[rows_df.country=='North America (EI)']
#Used to np.arrange to set boundaries(min,max,range)
#plt.hist(Asia_df['wind_consumption'], alpha=0.4, bins=np.arange(500,2500,100), label='Asia')
#plt.hist(Europe_df['wind_consumption'], alpha=0.4, bins=np.arange(500,2500,100), label='Europe')
#plt.hist(NorthAmerica_df['wind_consumption'], alpha=0.4, bins=np.arange(500,2500,100), label='North America')
plt.hist(Asia_df['wind_consumption'], alpha=0.4, bins=np.arange(500,2500,100), label='Asia')
plt.hist(Europe_df['wind_consumption'], alpha=0.4, bins=np.arange(500,2500,100), label='Europe')
plt.hist(North_America['wind_consumption'], alpha=0.4, bins=np.arange(500,2500,100), label='North America')
plt.legend('Selected_continents')
plt.title('Distribution of Wind Consumption in Asia, Europe and North America (EI)')
# Out:
# Text(0.5, 1.0, 'Distribution of Wind Consumption in Asia, Europe and North America (EI)')

# %%
#create pairplots with seaborn
selected_variable=['biofuel_consumption','wind_consumption']
sns.pairplot(rows_df, hue='country', vars=selected_variable)
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
